# %%
using HDF5
Natoms = 8
sigma = 1.0

Input_str = string("../training/data/Input_KS_MD_scf_", Natoms,"_sigma_", sigma,".h5")
Output_str = string("../training/data/Output_KS_MD_scf_", Natoms,"_sigma_", sigma,".h5")
# Out:
# "../training/data/Output_KS_MD_scf_8_sigma_1.0.h5"

# %%
Rho = h5open(Output_str, "r") do file
    read(file,"Rho")
end
Etotal = h5open(Output_str, "r") do file
    read(file,"Etotal")
end
Ftotal = h5open(Output_str, "r") do file
    read(file,"Ftotal")
end
X_traj = h5open(Input_str, "r") do file
    read(file,"R")
end
Etotal
# Out:
# 1×3000 Array{Float64,2}:
#  4.06071  4.06071  4.06071  4.06071  …  4.06004  4.06004  4.06004  4.06004

# %%
using PyPlot
Nit = length(Etotal)
plot(1:Nit, X_traj[:,1])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x133e5c748>

# %%
plot(1:Nit, X_traj[:,2])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x1326e7d30>
