# %%
# script to obtain the oscillating atoms using a vanilla verlet Integrator
# The main idea is to build a reference model to study the behavior fo the
# Neural network accelerated Molecular dynamic.

# we use the modelscf to compute the forces, and the velocity verlet algorithm
# to evolve the system.

# in this case we save the evolution of the system in a hd5f file.

include("../src/Atoms.jl")
include("../src/scfOptions.jl")
include("../src/anderson_mix.jl")
include("../src/kerker_mix.jl")
include("../src/Ham.jl")
include("../src/hartree_pot_bc.jl")
include("../src/pseudocharge.jl")
include("../src/getocc.jl")
include("../src/Integrators.jl")

# flag to save the data

# number of MD simulations and
Nit = 200

# getting all the parameters
dx = 0.5;
Nunit = 8;   # number of units
Lat = 10;     # size of the lattice
Ls = Nunit*Lat;
Ns = round(Integer, Ls / dx); # number of discretization points

# using the default values in Lin's code
YukawaK = 0.0100
n_extra = 10;
epsil0 = 10.0;
T_elec = 100.0;

kb = 3.1668e-6;
au2K = 315774.67;
Tbeta = au2K / T_elec;

betamix = 0.5;
mixdim = 10;

Ndist = 1;
Natoms = round(Integer, Nunit / Ndist);

sigma  = ones(Natoms,1)*(1.0);  # insulator
omega  = ones(Natoms,1)*0.03;
Eqdist = ones(Natoms,1)*10.0;
mass   = ones(Natoms,1)*42000.0;
nocc   = ones(Natoms,1)*2;          # number of electrons per atom
Z      = nocc;

function forces(x::Array{Float64,1})
    # input
    #       x: vector with the position of the atoms
    # output
    #       f: forces at the center of the atoms

    R = reshape(x, length(x), 1) # we need to make it a two dimensional array
    # creating an atom structure
    atoms = Atoms(Natoms, R, sigma,  omega,  Eqdist, mass, Z, nocc);
    # allocating a Hamiltonian
    ham = Ham(Lat, Nunit, n_extra, dx, atoms,YukawaK, epsil0, Tbeta)

    # total number of occupied orbitals
    Nocc = round(Integer, sum(atoms.nocc) / ham.nspin);

    # setting the options for the scf iteration
    mixOpts = andersonMixOptions(ham.Ns, betamix, mixdim )
    eigOpts = eigOptions(1.e-10, 1000, "eig");
    scfOpts = scfOptions(1.e-8, 300, eigOpts, mixOpts)

    # initialize the potentials within the Hemiltonian, setting H[\rho_0]
    init_pot!(ham, Nocc)

    # running the scf iteration
    VtoterrHist = scf!(ham, scfOpts)

    if VtoterrHist[end] > scfOpts.SCFtol
        println("convergence not achieved!! ")
    end

    # we compute the forces
    get_force!(ham)

    # computing the energy
    Vhar = hartree_pot_bc(ham.rho+ham.rhoa,ham);

    # NOTE: ham.Fband is only the band energy here.  The real total energy
    # is calculated using the formula below:
    Etot = ham.Eband + 1/2*sum((ham.rhoa-ham.rho).*Vhar)*dx;

    return ham.atoms.force[:]
end

# Setting the time evolution
dt = 1.0

x0 = zeros(Natoms); # this is defined as an 2D array
for j = 1:Natoms
  x0[j] = (j-0.5)*Lat*Ndist+dx;
end

x0[1] = x0[1] + 1.0

v0 = zeros(Natoms)
x1 = x0 + dt*v0

#### Computing the trajectories

(X_traj, v, vdot) = time_evolution(velocity_verlet, x -> forces(x), dt, Nit, x0, x1)

Rho    = zeros(Ns, Nit)
Etotal = zeros(1, Nit)
Ftotal = zeros(Natoms, Nit)


# we re-run the DFT computation using the trajectory
for ii = 1:Nit

    # we use the data of the evolved function
    R = reshape(X_traj[ii, :],Natoms,1)

    # creating an atom structure
    atoms = Atoms(Natoms, R, sigma,  omega,  Eqdist, mass, Z, nocc);

    # allocating a Hamiltonian
    ham = Ham(Lat, Nunit, n_extra, dx, atoms,YukawaK, epsil0, Tbeta)

    # total number of occupied orbitals
    Nocc = round(Integer, sum(atoms.nocc) / ham.nspin);

    # initialize the potentials within the Hemiltonian, setting H[\rho_0]
    init_pot!(ham, Nocc)

    # we use the anderson mixing of the potential
    mixOpts = andersonMixOptions(ham.Ns, betamix, mixdim )

    # we use the default options
    eigOpts = eigOptions(1.e-12, 1000, "eig");

    scfOpts = scfOptions(1.e-10, 3000, eigOpts, mixOpts)

    # running the scf iteration
    @time VtoterrHist = scf!(ham, scfOpts)

    # we compute the forces
    get_force!(ham)

    # computing the energy
    Vhar = hartree_pot_bc(ham.rho+ham.rhoa,ham);

    # NOTE: ham.Fband is only the band energy here.  The real total energy
    # is calculated using the formula below:
    Etot = ham.Eband + 1/2*sum((ham.rhoa-ham.rho).*Vhar)*dx;

    Etotal[ii] = Etot
    Ftotal[:,ii] = ham.atoms.force[:]
    Rho[:,ii] = ham.rho[:];

    println(length(VtoterrHist))
end

print("simulation finished")
# Out:
# initial conditions
# running the loop
# loop finished
#   0.523032 seconds (18.45 k allocations: 143.125 MiB, 3.09% gc time)
# 37
#   0.533554 seconds (18.94 k allocations: 146.996 MiB, 3.38% gc time)
# 38
#   0.504439 seconds (17.66 k allocations: 139.156 MiB, 2.54% gc time)
# 36
#   0.518736 seconds (18.15 k allocations: 143.028 MiB, 2.93% gc time)
# 37
#   0.506736 seconds (17.80 k allocations: 139.201 MiB, 2.56% gc time)
# 36
#   0.516717 seconds (18.29 k allocations: 143.073 MiB, 2.86% gc time)
# 37
#   0.476931 seconds (16.64 k allocations: 131.401 MiB, 2.68% gc time)
# 34
#   0.489232 seconds (17.24 k allocations: 135.310 MiB, 2.64% gc time)
# 35
#   0.494444 seconds (17.11 k allocations: 135.267 MiB, 2.64% gc time)
# 35
#   0.505558 seconds (17.25 k allocations: 135.312 MiB, 2.61% gc time)
# 35
#   0.514561 seconds (17.24 k allocations: 135.309 MiB, 2.82% gc time)
# 35
#   0.509836 seconds (17.09 k allocations: 135.261 MiB, 2.89% gc time)
# 35
#   0.493166 seconds (17.09 k allocations: 135.262 MiB, 2.59% gc time)
# 35
#   0.511290 seconds (17.24 k allocations: 135.310 MiB, 2.48% gc time)
# 35
#   0.532988 seconds (17.75 k allocations: 139.185 MiB, 2.47% gc time)
# 36
#   0.542379 seconds (17.64 k allocations: 139.152 MiB, 2.65% gc time)
# 36
#   0.517904 seconds (17.23 k allocations: 135.307 MiB, 2.47% gc time)
# 35
#   0.530844 seconds (18.01 k allocations: 139.269 MiB, 2.53% gc time)
# 36
#   0.485174 seconds (16.13 k allocations: 127.522 MiB, 2.85% gc time)
# 33
#   0.485902 seconds (16.23 k allocations: 127.557 MiB, 2.68% gc time)
# 33
#   0.458318 seconds (15.23 k allocations: 119.806 MiB, 2.62% gc time)
# 31
#   0.483403 seconds (16.57 k allocations: 131.380 MiB, 2.72% gc time)
# 34
#   0.521189 seconds (15.75 k allocations: 123.686 MiB, 3.06% gc time)
# 32
#   0.494572 seconds (16.10 k allocations: 127.514 MiB, 2.80% gc time)
# 33
#   0.489472 seconds (16.75 k allocations: 131.438 MiB, 2.73% gc time)
# 34
#   0.510299 seconds (16.77 k allocations: 131.442 MiB, 2.72% gc time)
# 34
#   0.500910 seconds (16.28 k allocations: 127.571 MiB, 2.17% gc time)
# 33
#   0.506487 seconds (16.79 k allocations: 131.450 MiB, 3.08% gc time)
# 34
#   0.489193 seconds (16.80 k allocations: 131.454 MiB, 2.58% gc time)
# 34
#   0.478643 seconds (16.65 k allocations: 131.404 MiB, 2.51% gc time)
# 34
#   0.465651 seconds (16.30 k allocations: 127.579 MiB, 2.58% gc time)
# 33
#   0.464544 seconds (16.28 k allocations: 127.572 MiB, 2.56% gc time)
# 33
#   0.478783 seconds (16.75 k allocations: 131.435 MiB, 2.46% gc time)
# 34
#   0.460971 seconds (16.12 k allocations: 127.521 MiB, 2.58% gc time)
# 33
#   0.473520 seconds (16.63 k allocations: 131.398 MiB, 2.53% gc time)
# 34
#   0.462789 seconds (16.28 k allocations: 127.570 MiB, 2.58% gc time)
# 33
#   0.450376 seconds (15.79 k allocations: 123.701 MiB, 2.22% gc time)
# 32
#   0.451540 seconds (15.80 k allocations: 123.703 MiB, 2.67% gc time)
# 32
#   0.472694 seconds (16.80 k allocations: 131.451 MiB, 2.50% gc time)
# 34
#   0.448836 seconds (15.81 k allocations: 123.705 MiB, 2.68% gc time)
# 32
#   0.458693 seconds (16.30 k allocations: 127.578 MiB, 2.17% gc time)
# 33
#   0.463398 seconds (16.29 k allocations: 127.573 MiB, 2.56% gc time)
# 33
#   0.460573 seconds (16.26 k allocations: 127.566 MiB, 2.59% gc time)
# 33
#   0.460445 seconds (16.07 k allocations: 127.506 MiB, 2.68% gc time)
# 33
#   0.474359 seconds (16.56 k allocations: 131.376 MiB, 2.50% gc time)
# 34
#   0.476010 seconds (16.58 k allocations: 131.382 MiB, 2.49% gc time)
# 34
#   0.472553 seconds (16.71 k allocations: 131.423 MiB, 2.54% gc time)
# 34
#   0.470669 seconds (16.67 k allocations: 131.412 MiB, 2.52% gc time)
# 34
#   0.488035 seconds (17.16 k allocations: 135.284 MiB, 2.44% gc time)
# 35
#   0.486200 seconds (17.16 k allocations: 135.284 MiB, 2.45% gc time)
# 35
#   0.500637 seconds (17.66 k allocations: 139.156 MiB, 2.77% gc time)
# 36
#   0.497777 seconds (17.66 k allocations: 139.157 MiB, 2.38% gc time)
# 36
#   0.499783 seconds (17.66 k allocations: 139.157 MiB, 2.39% gc time)
# 36
#   0.470301 seconds (16.67 k allocations: 131.410 MiB, 2.52% gc time)
# 34
#   0.476475 seconds (16.52 k allocations: 131.363 MiB, 2.50% gc time)
# 34
#   0.475448 seconds (16.76 k allocations: 131.440 MiB, 2.62% gc time)
# 34
#   0.510479 seconds (18.41 k allocations: 143.113 MiB, 2.74% gc time)
# 37
#   0.508882 seconds (18.33 k allocations: 143.086 MiB, 2.34% gc time)
# 37
#   0.522816 seconds (18.76 k allocations: 146.938 MiB, 2.66% gc time)
# 38
#   0.536668 seconds (19.40 k allocations: 150.860 MiB, 2.57% gc time)
# 39
#   0.535387 seconds (19.63 k allocations: 150.933 MiB, 2.60% gc time)
# 39
#   0.547100 seconds (19.79 k allocations: 154.698 MiB, 2.55% gc time)
# 40
#   0.548725 seconds (19.59 k allocations: 154.636 MiB, 2.52% gc time)
# 40
#   0.534420 seconds (19.26 k allocations: 150.813 MiB, 2.59% gc time)
# 39
#   0.534780 seconds (19.24 k allocations: 150.809 MiB, 2.61% gc time)
# 39
#   0.533365 seconds (19.26 k allocations: 150.813 MiB, 2.59% gc time)
# 39
#   0.519566 seconds (18.77 k allocations: 146.942 MiB, 2.29% gc time)
# 38
#   0.521515 seconds (18.77 k allocations: 146.944 MiB, 2.66% gc time)
# 38
#   0.522148 seconds (18.78 k allocations: 146.947 MiB, 2.66% gc time)
# 38
#   0.506023 seconds (18.33 k allocations: 143.086 MiB, 2.35% gc time)
# 37
#   0.507178 seconds (18.35 k allocations: 143.093 MiB, 2.71% gc time)
# 37
#   0.535301 seconds (19.33 k allocations: 150.837 MiB, 2.60% gc time)
# 39
#   0.464935 seconds (16.75 k allocations: 131.436 MiB, 2.59% gc time)
# 34
#   0.495864 seconds (18.11 k allocations: 139.303 MiB, 2.41% gc time)
# 36
#   0.536870 seconds (18.38 k allocations: 143.104 MiB, 2.70% gc time)
# 37
#   0.507611 seconds (18.32 k allocations: 143.083 MiB, 2.35% gc time)
# 37
#   0.482959 seconds (17.28 k allocations: 135.320 MiB, 2.46% gc time)
# 35
#   0.470555 seconds (16.75 k allocations: 131.436 MiB, 2.54% gc time)
# 34
#   0.511629 seconds (17.73 k allocations: 139.178 MiB, 2.72% gc time)
# 36
#   0.548085 seconds (17.22 k allocations: 135.303 MiB, 14.30% gc time)
# 35
#   0.483662 seconds (17.21 k allocations: 135.300 MiB, 2.40% gc time)
# 35
#   0.487641 seconds (17.05 k allocations: 135.249 MiB, 2.41% gc time)
# 35
#   0.481513 seconds (17.20 k allocations: 135.295 MiB, 2.41% gc time)
# 35
#   0.486189 seconds (17.05 k allocations: 135.247 MiB, 2.38% gc time)
# 35
#   0.514098 seconds (18.20 k allocations: 143.044 MiB, 2.66% gc time)
# 37
#   0.498175 seconds (17.73 k allocations: 139.181 MiB, 2.33% gc time)
# 36
#   0.499123 seconds (17.63 k allocations: 139.147 MiB, 2.71% gc time)
# 36
#   0.495759 seconds (17.83 k allocations: 139.213 MiB, 2.33% gc time)
# 36
#   0.509773 seconds (18.30 k allocations: 143.077 MiB, 2.30% gc time)
# 37
#   0.486489 seconds (17.26 k allocations: 135.314 MiB, 2.78% gc time)
# 35
#   0.506391 seconds (18.06 k allocations: 142.999 MiB, 2.29% gc time)
# 37
#   0.514301 seconds (18.18 k allocations: 143.040 MiB, 2.69% gc time)
# 37
#   0.498763 seconds (17.73 k allocations: 139.181 MiB, 2.35% gc time)
# 36
#   0.512286 seconds (18.50 k allocations: 143.140 MiB, 2.30% gc time)
# 37
#   0.471769 seconds (16.85 k allocations: 131.468 MiB, 2.50% gc time)
# 34
#   0.457080 seconds (16.20 k allocations: 127.547 MiB, 2.56% gc time)
# 33
#   0.455183 seconds (16.02 k allocations: 127.488 MiB, 2.58% gc time)
# 33
#   0.472511 seconds (16.70 k allocations: 131.420 MiB, 2.47% gc time)
# 34
#   0.470895 seconds (16.78 k allocations: 131.448 MiB, 2.48% gc time)
# 34
#   0.537263 seconds (19.41 k allocations: 150.862 MiB, 2.52% gc time)
# 39
#   0.553481 seconds (19.84 k allocations: 154.716 MiB, 2.48% gc time)
# 40
#   0.562380 seconds (19.37 k allocations: 150.848 MiB, 2.46% gc time)
# 39
#   0.571221 seconds (19.39 k allocations: 150.855 MiB, 2.66% gc time)
# 39
#   0.518134 seconds (17.87 k allocations: 139.223 MiB, 2.44% gc time)
# 36
#   0.544808 seconds (19.16 k allocations: 147.068 MiB, 2.70% gc time)
# 38
#   0.539372 seconds (19.04 k allocations: 147.029 MiB, 2.54% gc time)
# 38
#   0.538039 seconds (19.05 k allocations: 147.033 MiB, 2.33% gc time)
# 38
#   0.542343 seconds (18.94 k allocations: 146.996 MiB, 2.48% gc time)
# 38
#   0.558064 seconds (18.70 k allocations: 146.921 MiB, 2.56% gc time)
# 38
#   0.464255 seconds (16.13 k allocations: 127.524 MiB, 2.61% gc time)
# 33
#   0.466860 seconds (15.73 k allocations: 123.681 MiB, 2.15% gc time)
# 32
#   0.443140 seconds (15.19 k allocations: 119.791 MiB, 2.76% gc time)
# 31
#   0.462558 seconds (15.68 k allocations: 123.665 MiB, 2.14% gc time)
# 32
#   0.470145 seconds (16.18 k allocations: 127.538 MiB, 2.59% gc time)
# 33
#   0.484094 seconds (16.67 k allocations: 131.411 MiB, 2.62% gc time)
# 34
#   0.461215 seconds (15.68 k allocations: 123.664 MiB, 2.75% gc time)
# 32
#   0.478160 seconds (16.52 k allocations: 131.364 MiB, 2.38% gc time)
# 34
#   0.461654 seconds (16.18 k allocations: 127.538 MiB, 2.56% gc time)
# 33
#   0.475303 seconds (16.67 k allocations: 131.412 MiB, 2.49% gc time)
# 34
#   0.458340 seconds (16.02 k allocations: 127.488 MiB, 2.17% gc time)
# 33
#   0.445393 seconds (15.68 k allocations: 123.664 MiB, 2.72% gc time)
# 32
#   0.459319 seconds (15.68 k allocations: 123.664 MiB, 2.56% gc time)
# 32
#   0.470064 seconds (16.17 k allocations: 127.538 MiB, 2.18% gc time)
# 33
#   0.469866 seconds (16.17 k allocations: 127.538 MiB, 2.54% gc time)
# 33
#   0.486289 seconds (16.53 k allocations: 131.365 MiB, 2.55% gc time)
# 34
#   0.468699 seconds (16.02 k allocations: 127.488 MiB, 2.65% gc time)
# 33
#   0.485117 seconds (16.51 k allocations: 131.361 MiB, 2.33% gc time)
# 34
#   0.484519 seconds (16.67 k allocations: 131.411 MiB, 2.44% gc time)
# 34
#   0.490688 seconds (16.51 k allocations: 131.361 MiB, 2.39% gc time)
# 34
#   0.486748 seconds (16.70 k allocations: 131.422 MiB, 2.43% gc time)
# 34
#   0.476076 seconds (16.27 k allocations: 127.569 MiB, 2.43% gc time)
# 33
#   0.492260 seconds (16.96 k allocations: 131.504 MiB, 2.59% gc time)
# 34
#   0.477478 seconds (15.63 k allocations: 123.649 MiB, 2.55% gc time)
# 32
#   0.518671 seconds (16.74 k allocations: 131.433 MiB, 2.38% gc time)
# 34
#   0.465013 seconds (16.22 k allocations: 127.552 MiB, 2.17% gc time)
# 33
#   0.447305 seconds (15.69 k allocations: 123.669 MiB, 2.64% gc time)
# 32
#   0.448868 seconds (15.53 k allocations: 123.617 MiB, 2.61% gc time)
# 32
#   0.442416 seconds (15.69 k allocations: 123.668 MiB, 2.23% gc time)
# 32
#   0.472406 seconds (16.69 k allocations: 131.417 MiB, 2.51% gc time)
# 34
#   0.459328 seconds (16.06 k allocations: 127.501 MiB, 2.60% gc time)
# 33
#   0.472492 seconds (16.73 k allocations: 131.429 MiB, 2.52% gc time)
# 34
#   0.461062 seconds (16.27 k allocations: 127.567 MiB, 2.56% gc time)
# 33
#   0.460584 seconds (16.18 k allocations: 127.538 MiB, 2.58% gc time)
# 33
#   0.459105 seconds (16.23 k allocations: 127.556 MiB, 2.57% gc time)
# 33
#   0.456163 seconds (16.39 k allocations: 127.608 MiB, 2.17% gc time)
# 33
#   0.456126 seconds (16.40 k allocations: 127.609 MiB, 2.58% gc time)
# 33
#   0.464786 seconds (16.38 k allocations: 127.605 MiB, 2.53% gc time)
# 33
#   0.469335 seconds (16.91 k allocations: 131.488 MiB, 2.53% gc time)
# 34
#   0.566621 seconds (20.49 k allocations: 158.637 MiB, 2.41% gc time)
# 41
#   0.539226 seconds (19.34 k allocations: 150.838 MiB, 2.56% gc time)
# 39
#   0.531895 seconds (18.90 k allocations: 146.985 MiB, 2.68% gc time)
# 38
#   0.527492 seconds (18.95 k allocations: 146.998 MiB, 2.61% gc time)
# 38
#   0.575959 seconds (20.07 k allocations: 154.790 MiB, 2.46% gc time)
# 40
#   0.651373 seconds (20.11 k allocations: 154.800 MiB, 3.83% gc time)
# 40
#   0.547758 seconds (19.59 k allocations: 150.918 MiB, 3.08% gc time)
# 39
#   0.523565 seconds (18.94 k allocations: 146.997 MiB, 2.25% gc time)
# 38
#   0.538805 seconds (19.46 k allocations: 150.878 MiB, 2.55% gc time)
# 39
#   0.511116 seconds (18.32 k allocations: 143.084 MiB, 2.71% gc time)
# 37
#   0.524222 seconds (18.95 k allocations: 147.001 MiB, 2.24% gc time)
# 38
#   0.522510 seconds (18.91 k allocations: 146.986 MiB, 2.61% gc time)
# 38
#   0.525869 seconds (18.88 k allocations: 146.976 MiB, 2.62% gc time)
# 38
#   0.498000 seconds (17.88 k allocations: 139.227 MiB, 2.37% gc time)
# 36
#   0.458004 seconds (16.27 k allocations: 127.569 MiB, 2.59% gc time)
# 33
#   0.456032 seconds (16.24 k allocations: 127.558 MiB, 2.58% gc time)
# 33
#   0.470133 seconds (16.70 k allocations: 131.422 MiB, 2.52% gc time)
# 34
#   0.456833 seconds (16.18 k allocations: 127.539 MiB, 2.61% gc time)
# 33
#   0.483071 seconds (17.16 k allocations: 135.284 MiB, 2.46% gc time)
# 35
#   0.457605 seconds (16.17 k allocations: 127.536 MiB, 2.58% gc time)
# 33
#   0.455118 seconds (16.18 k allocations: 127.538 MiB, 2.18% gc time)
# 33
#   0.442550 seconds (15.68 k allocations: 123.663 MiB, 2.70% gc time)
# 32
#   0.457593 seconds (16.20 k allocations: 127.545 MiB, 2.59% gc time)
# 33
#   0.459316 seconds (16.21 k allocations: 127.548 MiB, 2.60% gc time)
# 33
#   0.572410 seconds (16.73 k allocations: 131.430 MiB, 3.41% gc time)
# 34
#   0.552601 seconds (16.25 k allocations: 127.562 MiB, 3.29% gc time)
# 33
#   0.460039 seconds (16.12 k allocations: 127.519 MiB, 2.31% gc time)
# 33
#   0.475683 seconds (16.27 k allocations: 127.569 MiB, 2.58% gc time)
# 33
#   0.528268 seconds (16.78 k allocations: 131.448 MiB, 3.32% gc time)
# 34
#   0.536193 seconds (16.78 k allocations: 131.447 MiB, 3.61% gc time)
# 34
#   0.457998 seconds (16.30 k allocations: 127.579 MiB, 2.64% gc time)
# 33
#   0.455395 seconds (16.31 k allocations: 127.580 MiB, 2.67% gc time)
# 33
#   0.457482 seconds (16.30 k allocations: 127.579 MiB, 2.64% gc time)
# 33
#   0.471012 seconds (16.66 k allocations: 131.406 MiB, 2.58% gc time)
# 34
#   0.680095 seconds (16.31 k allocations: 127.580 MiB, 3.97% gc time)
# 33
#   0.527657 seconds (16.72 k allocations: 131.427 MiB, 3.07% gc time)
# 34
#   0.458841 seconds (16.16 k allocations: 127.535 MiB, 2.65% gc time)
# 33
#   0.455753 seconds (16.21 k allocations: 127.550 MiB, 2.66% gc time)
# 33
#   0.456151 seconds (16.17 k allocations: 127.538 MiB, 2.64% gc time)
# 33
#   0.454530 seconds (16.02 k allocations: 127.488 MiB, 2.66% gc time)
# 33
#   0.459397 seconds (16.17 k allocations: 127.537 MiB, 2.62% gc time)
# 33
#   0.514859 seconds (16.17 k allocations: 127.536 MiB, 2.75% gc time)
# 33
#   0.567266 seconds (16.17 k allocations: 127.536 MiB, 3.20% gc time)
# 33
#   0.472860 seconds (16.66 k allocations: 131.409 MiB, 2.52% gc time)
# 34
#   0.492255 seconds (16.66 k allocations: 131.409 MiB, 2.44% gc time)
# 34
#   0.606157 seconds (16.66 k allocations: 131.409 MiB, 3.87% gc time)
# 34
#   0.477519 seconds (16.66 k allocations: 131.409 MiB, 2.53% gc time)
# 34
#   0.503526 seconds (16.17 k allocations: 127.537 MiB, 2.42% gc time)
# 33
#   0.478002 seconds (16.17 k allocations: 127.537 MiB, 2.89% gc time)
# 33
#   0.488682 seconds (16.67 k allocations: 131.410 MiB, 2.50% gc time)
# 34
#   0.483742 seconds (16.18 k allocations: 127.538 MiB, 2.20% gc time)
# 33
#   0.529710 seconds (17.20 k allocations: 135.297 MiB, 2.64% gc time)
# 35
# simulation finished

# %%
X_traj
# Out:
# 201×8 Array{Float64,2}:
#  6.5      15.5     25.5     35.5     45.5     55.5     65.5     75.5
#  6.49918  15.5006  25.5     35.5     45.5     55.5     65.5     75.5002
#  6.49671  15.5025  25.5     35.5     45.5     55.5     65.5     75.5008
#  6.49262  15.5055  25.5     35.5     45.5     55.5     65.5     75.5019
#  6.48691  15.5097  25.5     35.5     45.5     55.5     65.5     75.5033
#  6.4796   15.5152  25.5     35.5     45.5     55.5     65.5     75.5052
#  6.47073  15.5217  25.5001  35.5     45.5     55.5     65.5     75.5075
#  6.46031  15.5294  25.5001  35.5     45.5     55.5     65.5     75.5101
#  6.4484   15.5382  25.5002  35.5     45.5     55.5     65.5001  75.5132
#  6.43504  15.548   25.5002  35.5     45.5     55.5     65.5001  75.5167
#  6.42026  15.5587  25.5004  35.5     45.5     55.5     65.5001  75.5205
#  6.40412  15.5704  25.5005  35.5     45.5     55.5     65.5002  75.5248
#  6.38667  15.583   25.5007  35.5     45.5     55.5     65.5002  75.5294
#  ⋮                                             ⋮
#  5.2824   15.7738  25.3885  35.9073  46.117   55.5477  65.2995  75.6838
#  5.27703  15.7783  25.3904  35.8975  46.1067  55.5469  65.3158  75.6875
#  5.27227  15.7822  25.3928  35.8875  46.0956  55.5465  65.3324  75.6907
#  5.26814  15.7855  25.3958  35.8775  46.0839  55.5464  65.3494  75.6933
#  5.26465  15.7881  25.3995  35.8673  46.0716  55.5466  65.3668  75.6954
#  5.26181  15.7902  25.4036  35.857   46.0587  55.5473  65.3845  75.6969
#  5.25962  15.7917  25.4084  35.8465  46.0453  55.5482  65.4025  75.6979
#  5.25809  15.7926  25.4137  35.8359  46.0312  55.5495  65.4207  75.6982
#  5.25721  15.7928  25.4196  35.8253  46.0166  55.5511  65.4393  75.6981
#  5.25701  15.7925  25.426   35.8145  46.0014  55.5531  65.458   75.6974
#  5.25746  15.7916  25.433   35.8036  45.9858  55.5554  65.477   75.6962
#  5.25857  15.7901  25.4404  35.7926  45.9696  55.558   65.4962  75.6944

# %%
Etotal
# Out:
# 1×200 Array{Float64,2}:
#  4.06071  4.06071  4.0607  4.06069  …  4.06036  4.06035  4.06033  4.06031

# %%
Ftotal
# Out:
# 8×200 Array{Float64,2}:
#  -0.00164428   -0.00164116   -0.00163186   …   0.00066172    0.000659375
#   0.00122679    0.0012235     0.00121365      -0.000583762  -0.000575348
#   3.84282e-7    8.01813e-7    2.0533e-6        0.000522854   0.000506886
#  -1.51814e-8   -1.48675e-8   -1.36719e-8      -0.000100976  -9.55714e-5
#  -8.99772e-10  -9.01828e-10  -9.34375e-10     -0.000508759  -0.000486422
#  -4.8674e-9    -4.75563e-9   -4.35938e-9   …   0.000324917   0.000317746
#   1.4828e-7     2.90204e-7    7.15361e-7       0.0002122     0.000188944
#   0.000416976   0.000416595   0.000415453     -0.000528195  -0.000515609

# %%
using PyPlot
plot(1:201, X_traj[:,1])
# Out:
# PyError ($(Expr(:escape, :(ccall(#= /Users/jeffzzzz/.julia/packages/PyCall/RQjD7/src/pyfncall.jl:44 =# @pysym(:PyObject_Call), PyPtr, (PyPtr, PyPtr, PyPtr), o, pyargsptr, kw))))) <class 'ValueError'>
# ValueError('x and y must have same first dimension, but have shapes (200,) and (201,)')
#   File "/Users/jeffzzzz/.julia/conda/3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 2811, in plot
#     is not None else {}), **kwargs)
#   File "/Users/jeffzzzz/.julia/conda/3/lib/python3.7/site-packages/matplotlib/__init__.py", line 1810, in inner
#     return func(ax, *args, **kwargs)
#   File "/Users/jeffzzzz/.julia/conda/3/lib/python3.7/site-packages/matplotlib/axes/_axes.py", line 1611, in plot
#     for line in self._get_lines(*args, **kwargs):
#   File "/Users/jeffzzzz/.julia/conda/3/lib/python3.7/site-packages/matplotlib/axes/_base.py", line 393, in _grab_next_args
#     yield from self._plot_args(this, kwargs)
#   File "/Users/jeffzzzz/.julia/conda/3/lib/python3.7/site-packages/matplotlib/axes/_base.py", line 370, in _plot_args
#     x, y = self._xy_from_xy(x, y)
#   File "/Users/jeffzzzz/.julia/conda/3/lib/python3.7/site-packages/matplotlib/axes/_base.py", line 231, in _xy_from_xy
#     "have shapes {} and {}".format(x.shape, y.shape))
#
#
# Stacktrace:
#  [1] pyerr_check at /Users/jeffzzzz/.julia/packages/PyCall/RQjD7/src/exception.jl:60 [inlined]
#  [2] pyerr_check at /Users/jeffzzzz/.julia/packages/PyCall/RQjD7/src/exception.jl:64 [inlined]
#  [3] macro expansion at /Users/jeffzzzz/.julia/packages/PyCall/RQjD7/src/exception.jl:84 [inlined]
#  [4] __pycall!(::PyCall.PyObject, ::Ptr{PyCall.PyObject_struct}, ::PyCall.PyObject, ::Ptr{Nothing}) at /Users/jeffzzzz/.julia/packages/PyCall/RQjD7/src/pyfncall.jl:44
#  [5] _pycall!(::PyCall.PyObject, ::PyCall.PyObject, ::Tuple{UnitRange{Int64},Array{Float64,1}}, ::Int64, ::Ptr{Nothing}) at /Users/jeffzzzz/.julia/packages/PyCall/RQjD7/src/pyfncall.jl:22
#  [6] _pycall!(::PyCall.PyObject, ::PyCall.PyObject, ::Tuple{UnitRange{Int64},Array{Float64,1}}, ::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /Users/jeffzzzz/.julia/packages/PyCall/RQjD7/src/pyfncall.jl:11
#  [7] #pycall#100(::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}, ::Function, ::PyCall.PyObject, ::Type{PyCall.PyAny}, ::UnitRange{Int64}, ::Vararg{Any,N} where N) at /Users/jeffzzzz/.julia/packages/PyCall/RQjD7/src/pyfncall.jl:86
#  [8] pycall(::PyCall.PyObject, ::Type{PyCall.PyAny}, ::UnitRange{Int64}, ::Vararg{Any,N} where N) at /Users/jeffzzzz/.julia/packages/PyCall/RQjD7/src/pyfncall.jl:86
#  [9] #plot#85(::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}, ::Function, ::UnitRange{Int64}, ::Vararg{Any,N} where N) at /Users/jeffzzzz/.julia/packages/PyPlot/KRYZs/src/PyPlot.jl:178
#  [10] plot(::UnitRange{Int64}, ::Vararg{Any,N} where N) at /Users/jeffzzzz/.julia/packages/PyPlot/KRYZs/src/PyPlot.jl:175
#  [11] top-level scope at In[5]:2
